# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter(
    x=[1,3.2,5.4,7.6,9.8,12.5],
    y=[1,3,5.4,6.7,8,7.1],
    text=['A<br>size:130','B<br>size:90','C<br>size:75','D<br>size:100'],
    mode='markers',
    marker= dict(
        color=[100,110,120,130,140],
        size=[15,30,55,70,90,110],
        showscale=True )
)])
fig.show()
